# %% [markdown]
# **Projeto de Feature Engineering**

# %% [raw]
# Objetivo: Preparar dados de clientes para um modelo de previsão de churn (cancelamento), aplicando
# Feature Engineering, com ênfase em:
# - limpeza
# - criação de feature simples
# - One-Hot Encoding

# %% [markdown]
# **Importando Bibliotecas**

# %%
import pandas as pd

# %% [markdown]
# **Trazendo o arquivo**

# %%
df = pd.read_csv('clientes_churn.csv')

# %% [markdown]
# **Verificações inicias do arquivo**

# %%
# Dados iniciais
df.head()
# Out:
#    cliente_id  idade genero     plano  tempo_cliente_meses  gasto_mensal  \
# 0           1     25      M    basico                    6          79.9
# 1           2     34      F   premium                   24         129.9
# 2           3     45      M  standard                   36          99.9
# 3           4     29      F    basico                   12          69.9
# 4           5     52      M   premium                   60         149.9
#
#    churn
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0

# %%
# Verificar tipos de dados das colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cliente_id           10 non-null     int64
#  1   idade                10 non-null     int64
#  2   genero               10 non-null     object
#  3   plano                10 non-null     object
#  4   tempo_cliente_meses  10 non-null     int64
#  5   gasto_mensal         10 non-null     float64
#  6   churn                10 non-null     int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 692.0+ bytes

# %% [raw]
# DESCRIÇÃO DOS DADOS
#
# Coluna - Descrição
# cliente_id - Identificador do cliente
# idade - Idade do cliente
# genero - M = masculino, F = feminino
# plano -Tipo de plano
# tempo_cliente_meses - Tempo de contrato
# gasto_mensal - Valor pago por mês
# churn	1 = cancelou, 0 = ativo

# %%
# Verificar a quantidade de colunas categóricas e numéricas
df.dtypes.value_counts()
# Out:
# int64      4
# object     2
# float64    1
# Name: count, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    6
# 1    4
# Name: count, dtype: int64

# %%
# Estatísticas iniciais

df.describe()
# Out:
#        cliente_id     idade  tempo_cliente_meses  gasto_mensal      churn
# count    10.00000  10.00000            10.000000     10.000000  10.000000
# mean      5.50000  36.40000            28.800000    107.400000   0.400000
# std       3.02765   9.72054            24.174367     35.059473   0.516398
# min       1.00000  23.00000             3.000000     59.900000   0.000000
# 25%       3.25000  29.50000             9.750000     82.400000   0.000000
# 50%       5.50000  35.50000            21.000000     97.400000   0.000000
# 75%       7.75000  44.00000            45.000000    137.400000   1.000000
# max      10.00000  52.00000            72.000000    159.900000   1.000000

# %% [markdown]
# **Verificação de dados nulos**

# %%
df.isnull().sum()

# Não consta valores ausentes.
# Out:
# cliente_id             0
# idade                  0
# genero                 0
# plano                  0
# tempo_cliente_meses    0
# gasto_mensal           0
# churn                  0
# dtype: int64

# %% [markdown]
# **Separar target**

# %%
X = df.drop(columns=['churn'])   
y = df['churn']

# %% [markdown]
# **Identificar valores categóricos**

# %%
X.select_dtypes(include='object').columns
# Out:
# Index(['genero', 'plano'], dtype='object')

# %% [markdown]
# **Aplicando One-Hot Encoding**

# %%
X_encoded = pd.get_dummies(
    X,
    columns=['genero', 'plano'],
    drop_first=True
)

# %%
X_encoded.head()
# Out:
#    cliente_id  idade  tempo_cliente_meses  gasto_mensal  genero_F  genero_M  \
# 0           1     25                    6          79.9     False      True
# 1           2     34                   24         129.9      True     False
# 2           3     45                   36          99.9     False      True
# 3           4     29                   12          69.9      True     False
# 4           5     52                   60         149.9     False      True
#
#    plano_basico  plano_premium  plano_standard
# 0          True          False           False
# 1         False           True           False
# 2         False          False            True
# 3          True          False           False
# 4         False           True           False

# %% [markdown]
# **Dataset final**

# %%
df_final = pd.concat([X_encoded, y], axis=1)

# %%
df_final.head()
# Out:
#    cliente_id  idade  tempo_cliente_meses  gasto_mensal  genero_M  \
# 0           1     25                    6          79.9      True
# 1           2     34                   24         129.9     False
# 2           3     45                   36          99.9      True
# 3           4     29                   12          69.9     False
# 4           5     52                   60         149.9      True
#
#    plano_premium  plano_standard  churn
# 0          False           False      1
# 1           True           False      0
# 2          False            True      0
# 3          False           False      1
# 4           True           False      0

# %%
# Dependendo da versão do pandas, pode ficar ainda como Boolean. Logo, precisa ser convertido em int.
df_final = pd.get_dummies(
    df,
    columns=['genero', 'plano'],
    drop_first=True,
    dtype=int
)

# %%
df_final = df_final.astype(int)

# %%
df_final['genero_M'].value_counts()
# Out:
# genero_M
# 1    5
# 0    5
# Name: count, dtype: int64
